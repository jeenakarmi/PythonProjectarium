# %%
tallies = {
    'I': 1,
    'V': 5,
    'X': 10,
    'L': 50,
    'C': 100,
    'D': 500,
    'M': 1000,
}

def RomanNumeralToDecimal(romanNumeral):
    sum = 0
    for i in range(len(romanNumeral) - 1):
        left = romanNumeral[i]
        right = romanNumeral[i + 1]
        if tallies[left] < tallies[right]:
            sum -= tallies[left]
        else:
            sum += tallies[left]
    sum += tallies[romanNumeral[-1]]
    return sum

user_input = input("Enter a Roman numeral: ").upper().strip()

result = RomanNumeralToDecimal(user_input)

if result == -1:
    print("Invalid Roman numeral. Please use valid characters: I, V, X, L, C, D, M.")
else:
    print(f"The decimal value of {user_input} is {result}")
# Out:
# The decimal value of X is 10

# %%
# using try catch
tallies = {
    'I': 1,
    'V': 5,
    'X': 10,
    'L': 50,
    'C': 100,
    'D': 500,
    'M': 1000,
}

def RomanNumeralToDecimal(romanNumeral):
    sum = 0
    try:
        for i in range(len(romanNumeral) - 1):
            left = romanNumeral[i]
            right = romanNumeral[i + 1]
            if tallies[left] < tallies[right]:
                sum -= tallies[left]
            else:
                sum += tallies[left]
        sum += tallies[romanNumeral[-1]]
        return sum
    except KeyError:
        return -1  # Indicates invalid Roman numeral

user_input = input("Enter a Roman numeral: ").upper().strip()

result = RomanNumeralToDecimal(user_input)

if result == -1:
    print("Invalid Roman numeral. Please use valid characters: I, V, X, L, C, D, M.")
else:
    print(f"The decimal value of {user_input} is {result}")
# Out:
# The decimal value of I is 1

# %%
import tkinter as tk
from tkinter import messagebox

tallies = {
    'I': 1,
    'V': 5,
    'X': 10,
    'L': 50,
    'C': 100,
    'D': 500,
    'M': 1000,
}

def RomanNumeralToDecimal(romanNumeral):
    sum = 0
    try:
        for i in range(len(romanNumeral) - 1):
            left = romanNumeral[i]
            right = romanNumeral[i + 1]
            if tallies[left] < tallies[right]:
                sum -= tallies[left]
            else:
                sum += tallies[left]
        sum += tallies[romanNumeral[-1]]
        return sum
    except KeyError:
        return -1  # Indicates invalid Roman numeral

def convert():
    roman = entry.get().upper().strip()
    result = RomanNumeralToDecimal(roman)
    if result == -1:
        messagebox.showerror("Invalid Input", "Invalid Roman numeral.\nUse I, V, X, L, C, D, M only.")
    else:
        output_label.config(text=f"Decimal value: {result}")

# GUI Setup
root = tk.Tk()
root.title("Roman Numeral to Decimal Converter")
root.geometry("350x180")
root.resizable(False, False)

# Input label
tk.Label(root, text="Enter Roman Numeral:", font=("Arial", 12)).pack(pady=10)

# Input field
entry = tk.Entry(root, font=("Arial", 14), justify='center')
entry.pack()

# Convert button
tk.Button(root, text="Convert", font=("Arial", 12), command=convert).pack(pady=10)

# Output label
output_label = tk.Label(root, text="", font=("Arial", 14), fg="green")
output_label.pack(pady=5)

# Run the GUI
root.mainloop()
